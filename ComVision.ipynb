# %%
from PIL import Image
from IPython.display import display

im = Image.open("flowers.jpg")
#pil_im.show()
im.resize
display(im.rotate(1))
# Out:
# <PIL.Image.Image image mode=RGB size=800x750 at 0x1F2812C1AC0>

# %%
type(pil_im)
# Out:
# PIL.JpegImagePlugin.JpegImageFile
